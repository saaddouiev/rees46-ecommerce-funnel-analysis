# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_parquet('/Applications/project_portfolio/cosmetics_cleaned.parquet')

# %%
df.shape
# Out:
# (19493208, 8)

# %%
df.dtypes
# Out:
# event_time      datetime64[us, UTC]
# event_type                      str
# product_id                    int32
# category_id                   int64
# brand                           str
# price                       float32
# user_id                       int32
# user_session                    str
# dtype: object

# %%
df.head(10)
# Out:
#                  event_time event_type  product_id          category_id  \
# 0 2019-10-01 00:00:00+00:00       cart     5773203  1487580005134238553
# 1 2019-10-01 00:00:03+00:00       cart     5773353  1487580005134238553
# 2 2019-10-01 00:00:07+00:00       cart     5881589  2151191071051219817
# 3 2019-10-01 00:00:07+00:00       cart     5723490  1487580005134238553
# 4 2019-10-01 00:00:15+00:00       cart     5881449  1487580013522845895
# 5 2019-10-01 00:00:16+00:00       cart     5857269  1487580005134238553
# 6 2019-10-01 00:00:19+00:00       cart     5739055  1487580008246412266
# 7 2019-10-01 00:00:24+00:00       cart     5825598  1487580009445982239
# 8 2019-10-01 00:00:25+00:00       cart     5698989  1487580006317032337
# 9 2019-10-01 00:00:26+00:00       view     5875317  2029082628195353599
#
#      brand  price    user_id                          user_session
# 0   runail   2.62  463240011  26dd6e6e-4dac-4778-8d2c-92e149dab885
# ...

# %%
df['event_time'].min(), df['event_time'].max()
# Out:
# (Timestamp('2019-10-01 00:00:00+0000', tz='UTC'),
#  Timestamp('2020-02-29 23:59:59+0000', tz='UTC'))

# %%
df['event_type'].value_counts(normalize=True) * 100
# Out:
# event_type
# view                49.382677
# cart                28.790997
# remove_from_cart    15.229248
# purchase             6.597077
# Name: proportion, dtype: float64

# %%
df.groupby(df['event_time'].dt.month)['event_type'].count()
# Out:
# event_time
# 1     4030967
# 2     3861640
# 10    3882508
# 11    4376918
# 12    3341175
# Name: event_type, dtype: int64

# %%
df.groupby('event_type')['price'].describe()
# Out:
#                       count       mean        std   min   25%   50%    75%  \
# event_type
# cart              5612289.0   5.255532  10.555905  0.05  1.59  3.16   5.56
# purchase          1285982.0   4.936514   8.918663  0.05  1.59  3.00   5.40
# remove_from_cart  2968669.0   5.309322  10.401467  0.05  1.83  3.46   5.56
# view              9626268.0  12.416622  25.665403  0.05  2.84  5.10  10.00
#
#                          max
# event_type
# cart              327.779999
# purchase          327.779999
# remove_from_cart  327.779999
# view              327.779999

# %%
df[df['event_type'] == 'cart']['price'].describe()
# Out:
# count    5.612289e+06
# mean     5.255532e+00
# std      1.055591e+01
# min      5.000000e-02
# 25%      1.590000e+00
# 50%      3.160000e+00
# 75%      5.560000e+00
# max      3.277800e+02
# Name: price, dtype: float64

# %%
df[df['event_type'] == 'purchase'].groupby('brand')['price'].sum().head(3)
# Out:
# brand
# Unknown     2.563156e+06
# airnails    2.176174e+04
# almea       3.675870e+03
# Name: price, dtype: float32

# %%
df['day_of_week'] = df['event_time'].dt.dayofweek
df[df['event_type'] == 'purchase'].groupby('day_of_week')['price'].mean()
# Out:
# day_of_week
# 0    5.014929
# 1    4.981772
# 2    4.963950
# 3    4.942827
# 4    4.879557
# 5    4.890745
# 6    4.868645
# Name: price, dtype: float32

# %%
# Out:
# brand
# eunyul        62.48
# dermal        54.76
# cosima        52.34
# supertan      48.63
# elskin        42.16
# soleo         37.21
# severina      34.84
# swarovski     31.24
# benovy        27.70
# nitrile       27.69
# airnails      27.43
# farmstay      27.14
# dizao         26.24
# levissime     25.34
# skinlite      25.01
# cettua        25.00
# igrobeauty    24.78
# smart         24.29
# shary         24.05
# de.lux        23.81
# dtype: float64
